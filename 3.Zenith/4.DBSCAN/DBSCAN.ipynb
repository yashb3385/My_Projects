# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_moons
X,y = make_moons(n_samples=250, noise = 0.05)
X.shape

# %%
# from sklearn.datasets import make_circles

# X, y = make_circles(
#     n_samples=1000,
#     factor=0.5,      # gap between inner & outer circle
#     noise=0.05,
#     random_state=42
# )

# %%
# from sklearn.datasets import make_swiss_roll

# X, t = make_swiss_roll(
#     n_samples=1500,
#     noise=0.2,
#     random_state=42
# )
# X = X[:, [0, 2]]

# %%
# from sklearn.datasets import make_blobs
# import numpy as np

# X, y = make_blobs(
#     n_samples=1000,
#     centers=3,
#     cluster_std=1.0,
#     random_state=42
# )

# # Nonlinear transformation
# X[:, 0] = X[:, 0] ** 2

# %%
X
# Out:
# array([[-2.90918738,  7.751289  ],
#        [ 6.24850469, 12.29903262],
#        [ 6.84252487, -9.4456038 ],
#        ...,
#        [-8.64110957,  3.15828682],
#        [-3.54530395,  8.01573014],
#        [12.05228481,  3.38610752]], shape=(1500, 2))

# %%
plt.scatter(X[:,0],X[:,1])

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
dbscan =  DBSCAN(eps = 0.3)
dbscan.fit(X_scaled)
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(1500,))

# %%
plt.scatter(X[:,0],X[:,1], c= dbscan.labels_)
# plt.scatter(X[:,0],X[:,1],c=y)
